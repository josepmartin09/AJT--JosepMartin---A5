# %%
class song:

    def __init__ ( self, titol, autor, durada):
        self.titol = titol
        self.autor = autor
        self.durada = durada

    def info ( self ):
        return f"{self.titol} - {self.autor} ({self.durada})"
    

class playlist:

    def __init__ ( self, song_list):
        self.song_list = song_list  
        song_list = []

    def afegir_canco ( self, canco):
        self.song_list.append(canco)

    def durada_total ( self):
        total = 0
        for i in self.song_list:
            total += i.durada
        return total

    def mostrar_playlist ( self):
        for n in self.song_list:
            print ( n.info())

    def canco_mes_llarga ( self):
        canco_mes_llarga = self.song_list[0]
        for x in self.song_list:
            if x.durada > canco_mes_llarga.durada:
                canco_mes_llarga = x
        return canco_mes_llarga.info()


canco1 = song ( "Nothing but a G Thang", "Dr. Dre", 4.45)

canco2 = song ( "All of the Lights", "Kanye West", 5.00)

playlist1 = playlist ( [canco1, canco2])

canco3 = song ( "Empire State of Mind", "Jay-Z", 4.36)  

playlist1.afegir_canco ( canco3)

print ( playlist1.durada_total())
print ( playlist1.canco_mes_llarga())
playlist1.mostrar_playlist()
# Out:
# 13.809999999999999
# All of the Lights - Kanye West (5.0)
# Nothing but a G Thang - Dr. Dre (4.45)
# All of the Lights - Kanye West (5.0)
# Empire State of Mind - Jay-Z (4.36)

# %%
class personatge:

    def __init__( self, nom, vida, forca, nivell ):
        self.nom = nom
        self.vida = vida
        self.forca = forca
        self.nivell = nivell

    def atacar ( self, enemic ):
        enemic.vida -= self.forca
            
        if enemic.vida < 0 :
                enemic.vida = 0
        else :
            print ( f"L'enemic {enemic.nom} ha perdut {self.forca}")
        
        return enemic.vida
        
    def pujar_nivell ( self):
        self.nivel += 1
        self.forca += 2
        self.vida += 5

    def esta_viu (self):
        if self.vida > 0 :
              return True
        else:
             return False
        
    def __str__ (self):
